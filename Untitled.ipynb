# %%
import pandas as pd
import os

# Path to your dataset folder
data_folder = "/Users/ritiktoksiya/Downloads/Capstone_606"

# Your dataset file name (make sure it matches exactly)
file_name = "diabetes_health_indicators(1).csv"  # change if needed

# Build full file path
file_path = os.path.join(data_folder, file_name)

# Load the dataset
df = pd.read_csv(file_path)

# Basic sanity checks
print("Dataset loaded successfully!")
print("Shape:", df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())

print("\nDataset info:")
df.info()
# Out:
# Dataset loaded successfully!
# Shape: (253680, 22)
#
# Column names:
# ['Diabetes_012', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education', 'Income']
#
# First 5 rows:
#   Diabetes_012 HighBP HighChol CholCheck   BMI Smoker Stroke  \
# 0  No diabetes    Yes      Yes       Yes  40.0    Yes     No
# 1  No diabetes     No       No        No  25.0    Yes     No
# 2  No diabetes    Yes      Yes       Yes  28.0     No     No
# 3  No diabetes    Yes       No       Yes  27.0     No     No
# 4  No diabetes    Yes      Yes       Yes  24.0     No     No
#
#   HeartDiseaseorAttack PhysActivity Fruits  ... AnyHealthcare NoDocbcCost  \
# 0                   No           No     No  ...           Yes          No
# 1                   No          Yes     No  ...            No         Yes
# 2                   No           No    Yes  ...           Yes         Yes
# 3                   No          Yes    Yes  ...           Yes          No
# 4                   No          Yes    Yes  ...           Yes          No
#
#      GenHlth MentHlth PhysHlth  DiffWalk     Sex    Age  \
# 0       Poor     18.0     15.0       Yes  Female  60-64
# 1       Good      0.0      0.0        No  Female  50-54
# 2       Poor     30.0     30.0       Yes  Female  60-64
# 3  Very good      0.0      0.0        No  Female  70-74
# 4  Very good      3.0      0.0        No  Female  70-74
#
#                          Education           Income
# 0       High school graduate / GED  $15,000–$20,000
# 1                 College graduate        < $10,000
# 2       High school graduate / GED        ≥ $75,000
# 3                      Grades 9–11  $35,000–$50,000
# 4  Some college / Technical school  $20,000–$25,000
#
# [5 rows x 22 columns]
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          253680 non-null  object
#  1   HighBP                253680 non-null  object
#  2   HighChol              253680 non-null  object
#  3   CholCheck             253680 non-null  object
#  4   BMI                   253680 non-null  float64
#  5   Smoker                253680 non-null  object
#  6   Stroke                253680 non-null  object
#  7   HeartDiseaseorAttack  253680 non-null  object
#  8   PhysActivity          253680 non-null  object
#  9   Fruits                253680 non-null  object
#  10  Veggies               253680 non-null  object
#  11  HvyAlcoholConsump     253680 non-null  object
#  12  AnyHealthcare         253680 non-null  object
#  13  NoDocbcCost           253680 non-null  object
#  14  GenHlth               253680 non-null  object
#  15  MentHlth              253680 non-null  float64
#  16  PhysHlth              253680 non-null  float64
#  17  DiffWalk              253680 non-null  object
#  18  Sex                   253680 non-null  object
#  19  Age                   253680 non-null  object
#  20  Education             253680 non-null  object
#  21  Income                253680 non-null  object
# dtypes: float64(3), object(19)
# memory usage: 42.6+ MB
